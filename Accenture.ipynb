# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ls
# Out:
# Content.csv        ReactionTypes.csv  Untitled.ipynb
# Final.csv          Reactions.csv      rtr.csv

# %%
content=pd.read_csv("Content.csv")
react=pd.read_csv("rtr.csv")

# %%
content.head()

# %%
merge1 = pd.merge(content,react, on="Content ID")
merge1.head()
# Out:
#    Unnamed: 0                            Content ID   Type  Category
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2  photo  Studying  \
# 1           0  97522e57-d9ab-4bd6-97bf-c24d952602d2  photo  Studying
# 2           0  97522e57-d9ab-4bd6-97bf-c24d952602d2  photo  Studying
# 3           0  97522e57-d9ab-4bd6-97bf-c24d952602d2  photo  Studying
# 4           0  97522e57-d9ab-4bd6-97bf-c24d952602d2  photo  Studying
#
#   Content ID.1     Content ID.2 Content ID.3  Content ID.4
# 0      disgust   7/11/2020 9:43     negative             0
# 1      dislike  17/6/2021 12:22     negative            10
# 2       scared   18/4/2021 5:13     negative            15
# 3      disgust   6/1/2021 19:13     negative             0
# 4   interested  23/8/2020 12:25     positive            30

# %%
merge1.columns
# Out:
# Index(['Unnamed: 0', 'Content ID', 'Type', 'Category', 'Content ID.1',
#        'Content ID.2', 'Content ID.3', 'Content ID.4'],
#       dtype='object')

# %%
merge1.shape
# Out:
# (24573, 8)

# %%
merge1.to_csv("Final2.csv")

# %%
data=pd.read_csv("Final2.csv")

# %%
data
# Out:
#          sno                            Content ID Content Type    Category
# 0          0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying  \
# 1          1  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# 2          2  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# 3          3  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# 4          4  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo    Studying
# ...      ...                                   ...          ...         ...
# 24568  24568  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 24569  24569  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 24570  24570  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 24571  24571  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
# 24572  24572  75d6b589-7fae-4a6d-b0d0-752845150e56        audio  technology
#
#       Content Responce         DateTime Sentiment  Score
# ...

# %%
# df.drop(['C', 'D'], axis=1)
data.drop(['sno'],axis=1,inplace=True)

# %%
top5Category=data[['Category','Score']].value_counts()
top5Category
# Out:
# Category         Score
# animals          70       240
# culture          70       229
# technology       70       226
# healthy eating   70       216
# food             70       214
#                          ...
# Culture          35         1
# Soccer           12         1
# Public Speaking  75         1
# Culture          5          1
# Public Speaking  15         1
# Name: count, Length: 400, dtype: int64

# %%
top5ContentType=data['Content Type'].value_counts()
top5ContentType
# Out:
# Content Type
# photo    6589
# video    6245
# GIF      6079
# audio    5660
# Name: count, dtype: int64

# %%
data.to_csv("FinalResult.csv")

# %%
data1=pd.read_csv("FinalResult.csv")

# %%
data.shape
# Out:
# (24573, 7)

# %%
data['Content Type'].value_counts().plot(kind='bar')
plt.show()

# %%
data['Category'].unique()
# Out:
# array(['Studying', 'healthy eating', 'technology', 'food', 'cooking',
#        'dogs', 'soccer', 'public speaking', 'science', 'tennis', 'travel',
#        'fitness', 'education', 'studying', 'veganism', 'Animals',
#        'animals', 'culture', 'Fitness', 'Veganism', 'Travel', 'Education',
#        'Technology', 'Soccer', 'Culture', 'Food', 'Healthy Eating',
#        'Science', 'Public Speaking'], dtype=object)

# %%
data['Category'].value_counts()
# Out:
# Category
# animals            1805
# healthy eating     1711
# technology         1695
# science            1680
# cooking            1664
# culture            1635
# travel             1618
# food               1608
# education          1397
# soccer             1392
# dogs               1338
# tennis             1328
# studying           1318
# fitness            1257
# veganism           1237
# public speaking    1185
# Fitness             138
# Science             116
# Animals              92
# Food                 91
# Soccer               65
# Studying             45
# Culture              41
# Education            36
# Public Speaking      32
# Travel               29
# Veganism             11
# Healthy Eating        6
# Technology            3
# Name: count, dtype: int64

# %%
data['Category'].nunique()
# Out:
# 29

# %%
top5c=data[['Category']].value_counts().head(5).plot(kind='bar')
plt.show()

# %%
data.head()
# Out:
#                              Content ID Content Type  Category
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  Studying  \
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  Studying
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  Studying
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  Studying
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo  Studying
#
#   Content Responce         DateTime Sentiment  Score
# 0          disgust   7/11/2020 9:43  negative      0
# 1          dislike  17/6/2021 12:22  negative     10
# 2           scared   18/4/2021 5:13  negative     15
# 3          disgust   6/1/2021 19:13  negative      0
# 4       interested  23/8/2020 12:25  positive     30

# %%
data['Content Responce'].nunique()
# Out:
# 16

# %%
data.groupby(['Category','Sentiment'])['Score'].sum().plot()
# Out:
# <AxesSubplot:xlabel='Category,Sentiment'>

# %%
data.DateTime.value_counts()
# Out:
# DateTime
# 9/2/2021 21:34      4
# 28/1/2021 17:31     3
# 28/8/2020 22:06     3
# 3/1/2021 5:06       3
# 24/7/2020 5:45      3
#                    ..
# 8/8/2020 7:09       1
# 28/11/2020 15:02    1
# 28/9/2020 2:11      1
# 18/5/2021 2:51      1
# 4/1/2021 4:55       1
# Name: count, Length: 24010, dtype: int64

# %%
sns.scatterplot(data=data,x="Category",y="Content Responce",hue="Score")
plt.xticks(rotation=90)
plt.show()
